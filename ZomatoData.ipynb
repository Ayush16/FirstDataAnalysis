# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

# %%
data = pd.read_csv('./world-development-indicators/zomato.csv',encoding='latin-1')
data.shape
# Out:
# (9551, 21)

# %%
data.head(15)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
mask1=data['Country Code']!=1

# %%
data[mask1].head(15)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
len(data[mask1])
# Out:
# 899

# %%
uniquecity=data['City'].unique().tolist()
len(uniquecity)
# Out:
# 141

# %%
data=data.drop(data.index[mask1])

# %%
len(data)
# Out:
# 8652

# %%
data.head(15)
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
# 629        3400325                              MoMo Cafe             1  Agra
# 630        3400059                  Peshawri - ITC Mughal             1  Agra
# 631        3400060                  Taj Bano - ITC Mughal             1  Agra
# 632        3400348                                 G Thal             1  Agra
# 633        3400072           Dawat-e-Nawab - Radisson Blu             1  Agra
# 634        3400073            The Latitude - Radisson Blu             1  Agra
# ...

# %%
data=data[data.City != 'New Delhi']
data=data[data.City != 'Gurgaon']
data=data[data.City != 'Noida']
data=data[data.City != 'Faridabad']
data=data[data.City != 'Secunderabad']
data=data[data.City != 'Mohali']
data=data[data.City != 'Panchkula']
uniquecity=data['City'].unique().tolist()
len(uniquecity)
#print(uniquecity)
# Out:
# 36

# %%
mask2 = data['City']=='Agra'

# %%
len(data[mask2])
# Out:
# 20

# %%
AgraRatings=data[mask2]

# %%
#average_rating = data[['City','Aggregate rating']].groupby('City').mean()
#print(average_rating)
city_count=data['City'].value_counts()
city_count.shape
#print(city_count)
#plt.pie(city_count)
#plt.show()
# Out:
# (36,)

# %%
average_rating_data=np.array(average_rating)
print(average_rating_data)
#average_rating_data.shape
uniquecity_rating=np.array(uniquecity)
uniquecity_rating.shape
# Out:
# [[3.965     ]
#  [4.16190476]
#  [3.395     ]
#  [3.68571429]
#  [3.375     ]
#  [4.375     ]
#  [3.95      ]
#  [3.98095238]
#  [4.05      ]
#  [4.315     ]
#  [4.135     ]
#  [4.05      ]
#  [1.86693227]
#  [2.852     ]
#  [4.245     ]
#  [2.65143113]
#  [4.19047619]
#  [4.34444444]
#  [3.97      ]
#  [4.13      ]
#  [3.815     ]
#  [4.08      ]
#  [4.255     ]
#  [4.1952381 ]
#  [3.98      ]
#  [3.745     ]
#  [4.3       ]
#  [4.085     ]
#  [3.695     ]
#  [3.965     ]
#  [3.52      ]
#  [2.43884524]
#  [2.0362037 ]
#  [4.2       ]
#  [3.455     ]
#  [3.73      ]
#  [4.22      ]
#  [3.455     ]
#  [4.5       ]
#  [3.935     ]
#  [4.025     ]
#  [3.51      ]
#  [4.005     ]]
# (43,)

# %%
plt.figure(figsize=(60,10))
plt.scatter(uniquecity_rating,average_rating_data)
for a,b in zip(uniquecity_rating, average_rating_data): 
    plt.text(a, b, str(b))
plt.show()

# %%
data_cuisines = data['Cuisines'].str.split(',', expand=True)
data_cuisines.shape
# Out:
# (8652, 8)

# %%
#t = pd.merge(data,data_cuisines,how='outer')
t=pd.concat([data, data_cuisines], axis=1)
t.head(20)
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
# 629        3400325                              MoMo Cafe             1  Agra
# 630        3400059                  Peshawri - ITC Mughal             1  Agra
# 631        3400060                  Taj Bano - ITC Mughal             1  Agra
# 632        3400348                                 G Thal             1  Agra
# 633        3400072           Dawat-e-Nawab - Radisson Blu             1  Agra
# 634        3400073            The Latitude - Radisson Blu             1  Agra
# ...
